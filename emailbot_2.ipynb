# %%
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient
from email.mime.text import MIMEText
from email.message import EmailMessage
import smtplib
import ssl

def get_votes(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    vote_count  = soup.find('div', {'class': 'uvIdeaVoteCount'}).find('strong').text
    return (vote_count)
    #print (vote_count)

def get_max_pages(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    pages = soup.find_all(['a', 'em'])

    page_numbers = [int(page.text) for page in pages if page.text.isdigit()]

    max_page = max(page_numbers)

    return (max_page)

def extract_number_from_url(url):
    try:
        parts = url.split('suggestions/')
        if len(parts) > 1:
            number = parts[1].split('-')[0]
            if number.isdigit():
                return int(number)
    except Exception as e:
        print(f"Error occurred: {str(e)}")
    return None



def scrape_website():
    headers_arr = []
    url_arr = []
    vote_arr = []
    id_arr =[]
    
    url = 'https://feedback.mongodb.com/search?filter=ideas&page=1&query=serverless'
    max_page = get_max_pages(url)

    i = 1

    while i <= max_page:
        url = 'https://feedback.mongodb.com/search?filter=ideas&page='+str(i)+'&query=serverless'
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        h3_tags = soup.find_all('h3')

        ##for tag in h3_tags:
            ##print(f'H3 Text: {tag.text.strip()}\n---')

        for tag in h3_tags:
            a_tag = tag.find('a')
            text = a_tag.text.strip()
            href = a_tag.get('href')
            headers_arr.append(text)
            url_arr.append("https://feedback.mongodb.com"+href)
            ##print(f'H3 Text: {text} \nURL: https://feedback.mongodb.com{href}\n---')

        i = i+1

    for url in url_arr:
        vote_ct= get_votes(url)
        vote_arr.append(vote_ct)


    for url in url_arr:
        post_ID = extract_number_from_url(url)
        id_arr.append(post_ID)

 #   print (headers_arr)
 #   print (url_arr)
 #   print (vote_arr)
 #   print (id_arr)

# Replace this with your MongoDB Atlas connection string
    mongo_connection_string = "" #insert connection string
    client = MongoClient(mongo_connection_string)

# Replace these with your database and collection names
    db = client['feedback']
    collection = db['serverless']

    n = 0
    email_text=[]
    for post_ID in id_arr:
        # Check if a document with this post_ID exists
        if collection.count_documents({'post_ID': post_ID}, limit = 1) == 0:
            new_doc = {'post_ID': post_ID, 'title': headers_arr[n], 'votes': vote_arr[n], 'url' : url_arr[n]}
            collection.insert_one(new_doc)
            txt = str(headers_arr[n])+"_"+str(post_ID)+" has just been created! Click here to learn more- "+url_arr[n]
            email_text.append(txt)
            print(f'Document with post_ID {post_ID} has been created.')
                
        post = collection.find_one({"post_ID": post_ID})

        print(headers_arr[n], post.get('votes', 0), vote_arr[n])

        if int(post.get('votes', 0)) < int(vote_arr[n]):
                print ("yes")
                collection.update_one({"post_ID": post_ID}, {"$set": {"votes": vote_arr[n]}})
                txt = str(headers_arr[n])+"_"+str(post_ID)+" has more votes. It now has "+ str(vote_arr[n])+" votes. URL- "+url_arr[n]
                email_text.append(txt)
        
        n = n+1
    
    if email_text ==[]:
        email_text = ["There are no new updates"]
    
    email_text_string = '\n'.join(email_text)

    print(email_text_string)

    email_sender = ''#insert sender email 
    email_password = '' #insert sender password

    email_receiver = '' #insert recipient email 

    subject = "" #insert subject

    body = email_text_string

    em = EmailMessage()
    em['From'] = email_sender
    em['To'] = email_receiver
    em['subject'] = subject

    em.set_content(body)

    context = ssl.create_default_context()

    with smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context) as smtp:
        smtp.login(email_sender, email_password)
        smtp.sendmail(email_sender, email_receiver, em.as_string())


if __name__ == "__main__":
    scrape_website()
# Out:
# Document with post_ID 48499670 has been created.
# Support for serverless 1 1
# change streams serverless 9 10
# yes
# Atlas Search on serverless instances 14 18
# yes
# Terraform Serverless VPC Endpoint configuration 8 8
# Add Datadog integration to Atlas Serverless 7 9
# yes
# Serverless RPU estimator 7 9
# yes
# Restored snapshots from a dedicated instance to a serverless instance 5 5
# Atlas triggers on serverless instance 2 2
# serverless 8 10
# yes
# Support serverless OLAP workloads 1 2
# yes
# Document with post_ID 48610703 has been created.
# Add support for logs on serverless instances 1 1
# Programatically disable/enable Auto indexing Serverless 14 15
# yes
# Document with post_ID 48268316 has been created.
# allow atlas search for serverless instances 1 1
# Introduce serverless clusters for GCP Frankfurt region 4 4
# Add EventBridge integration for Serverless instances 2 2
# Allow turning off backups on serverless and free instances 3 2
# Serverless instances on AWS Paris (eu-west-3) region 9 11
# yes
# Introduce Serverless for AWS Frankfurt region 1 1
# Serverless instances on AWS South American region 10 10
# Support GCP private link with Serverless clusters 1 2
# yes
# Realm device-sync for serverless instance 1 1
# Document with post_ID 48617588 has been created.
# Device Sync for serverless instance 1 1
# Budget limit for serverless pay as you go mode 3 4
# yes
# mongodbatlas_serverless_privatelink_endpoint 3 3
# Document with post_ID 48362240 has been created.
# Support for CDK SAM Template in Publishing Serverless Applications in AWS 1 1
# Incremental backup on Serverless Instances 1 1
# Document with post_ID 48475481 has been created.
# Realm Flexible device sync on serverless instance for small mobile apps 1 1
# Serverless queries could return their RPU & WPU along with the results 1 1
# Document with post_ID 48217358 has been created.
# serverless concurrent connection limit 1 1
# Permit downloading of serverless instance snapshots. 2 2
# Local development tooling 155 159
# yes
# Serverless instances on AWS eu-central-1 region 2 4
# yes
# Document with post_ID 48587330 has been created.
# South Africa Region 1 1
# Support europe-west4 in GCP 1 1
# Offer serverless in more AWS regions (like me-south-1) 1 1
# Enable Atlas Device Sync support on Atlas serverless Instances 1 1
# AtlasBasic CDK 1 1
# Mongodb Atlas in the ca-west-1 AWS region 1 1
# Document with post_ID 48550778 has been created.
# Add a function for determining if a connection object is still healthy 5 5
# grpc 1 1
# Shared Clusters upgrade to MongoDB 6.0+ 2 2
# Support for MongoDB Package in Edge Computing Environments 1 1
# Document with post_ID 48328340 has been created.
# Always show an option for both SRV Connection String and Standard Connection String 1 1
# MongoDB Connection Pool Proxy 2 3
# yes
# Create Org via API 3 3
# Document with post_ID 48601235 has been created.
# Exploring MongoDB's Role in Event Sourcing and Kubernetes for Payment Processing 2 2
# Support for serverless_48499670 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/958874-atlas-stream-processing/suggestions/48499670-support-for-serverless
# change streams serverless_45412816 has more votes. It now has 10 votes. URL- https://feedback.mongodb.com/forums/924145-atlas/suggestions/45412816-change-streams-serverless
# Atlas Search on serverless instances_45997066 has more votes. It now has 18 votes. URL- https://feedback.mongodb.com/forums/924868-atlas-search/suggestions/45997066-atlas-search-on-serverless-instances
# Add Datadog integration to Atlas Serverless_45688906 has more votes. It now has 9 votes. URL- https://feedback.mongodb.com/forums/924145-atlas/suggestions/45688906-add-datadog-integration-to-atlas-serverless
# Serverless RPU estimator_46299088 has more votes. It now has 9 votes. URL- https://feedback.mongodb.com/forums/924145-atlas/suggestions/46299088-serverless-rpu-estimator
# serverless_44656425 has more votes. It now has 10 votes. URL- https://feedback.mongodb.com/forums/924145-atlas/suggestions/44656425-serverless
# Support serverless OLAP workloads_45501136 has more votes. It now has 2 votes. URL- https://feedback.mongodb.com/forums/924145-atlas/suggestions/45501136-support-serverless-olap-workloads
# Add support for logs on serverless instances_48610703 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/923524-charts/suggestions/48610703-add-support-for-logs-on-serverless-instances
# Programatically disable/enable Auto indexing Serverless_47447948 has more votes. It now has 15 votes. URL- https://feedback.mongodb.com/forums/924145-atlas/suggestions/47447948-programatically-disable-enable-auto-indexing-serve
# allow atlas search for serverless instances_48268316 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/924868-atlas-search/suggestions/48268316-allow-atlas-search-for-serverless-instances
# Serverless instances on AWS Paris (eu-west-3) region_46107703 has more votes. It now has 11 votes. URL- https://feedback.mongodb.com/forums/924145-atlas/suggestions/46107703-serverless-instances-on-aws-paris-eu-west-3-regi
# Support GCP private link with Serverless clusters_47421017 has more votes. It now has 2 votes. URL- https://feedback.mongodb.com/forums/924145-atlas/suggestions/47421017-support-gcp-private-link-with-serverless-clusters
# Device Sync for serverless instance_48617588 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/945334-atlas-app-services/suggestions/48617588-device-sync-for-serverless-instance
# Budget limit for serverless pay as you go mode_46350253 has more votes. It now has 4 votes. URL- https://feedback.mongodb.com/forums/924280-database/suggestions/46350253-budget-limit-for-serverless-pay-as-you-go-mode
# Support for CDK SAM Template in Publishing Serverless Applications in AWS_48362240 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/924145-atlas/suggestions/48362240-support-for-cdk-sam-template-in-publishing-serverl
# Realm Flexible device sync on serverless instance for small mobile apps_48475481 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/923521-realm/suggestions/48475481-realm-flexible-device-sync-on-serverless-instance
# serverless concurrent connection limit_48217358 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/924145-atlas/suggestions/48217358-serverless-concurrent-connection-limit
# Local development tooling_40550575 has more votes. It now has 159 votes. URL- https://feedback.mongodb.com/forums/945334-atlas-app-services/suggestions/40550575-local-development-tooling
# Serverless instances on AWS eu-central-1 region_46586629 has more votes. It now has 4 votes. URL- https://feedback.mongodb.com/forums/924145-atlas/suggestions/46586629-serverless-instances-on-aws-eu-central-1-region
# South Africa Region_48587330 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/924145-atlas/suggestions/48587330-south-africa-region
# Add a function for determining if a connection object is still healthy_48550778 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/924286-drivers/suggestions/48550778-add-a-function-for-determining-if-a-connection-obj
# Always show an option for both SRV Connection String and Standard Connection String_48328340 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/924145-atlas/suggestions/48328340-always-show-an-option-for-both-srv-connection-stri
# MongoDB Connection Pool Proxy_46031320 has more votes. It now has 3 votes. URL- https://feedback.mongodb.com/forums/924145-atlas/suggestions/46031320-mongodb-connection-pool-proxy
# Exploring MongoDB's Role in Event Sourcing and Kubernetes for Payment Processing_48601235 has just been created! Click here to learn more- https://feedback.mongodb.com/forums/924145-atlas/suggestions/48601235-exploring-mongodb-s-role-in-event-sourcing-and-kub

# %%
mongo_connection_string = "mongodb+srv://anurag_admin:anurag_admin@feedbackenginetracker.8btkvdb.mongodb.net/"
client = MongoClient(mongo_connection_string)
db = client['feedback']
collection = db['serverless']
post= collection.find_one({"post_ID": 46229065})
post.get('votes', 0)
# Out:
# Running cells with '/usr/bin/python3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
